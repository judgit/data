# %% [markdown]
# <a href="https://colab.research.google.com/github/judgit/data/blob/master/notebook/JUDGIT%E3%83%87%E3%83%BC%E3%82%BF%E6%8A%95%E5%85%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# %%bigquery --project=judgit-nu
# LOAD DATA INTO `judgit-nu.2023.judgit`
# (
#     id INT64,
#     project_id INT64,
#     url STRING,
#     report_year INT64,
#     project_name STRING,
#     start_year INT64,
#     end_year INT64,
#     ministry STRING,
#     project_number STRING,
#     project_number1 STRING,
#     project_number2 STRING,
#     project_number3 STRING,
#     project_number4 STRING,
#     project_number5 STRING,
#     bureau STRING,
#     department STRING,
#     author STRING,
#     accounting_category ARRAY<STRING>,
#     objective STRING,
#     summary STRING,
#     method ARRAY<STRING>,
#     categories ARRAY<STRING>,
#     expenses_category ARRAY<STRING>,
#     budget ARRAY<STRUCT<year INT64, original FLOAT64, supplementary FLOAT64, brought FLOAT64, carried FLOAT64, reserve FLOAT64, total FLOAT64, executed FLOAT64, request FLOAT64>>,
#     payee ARRAY<STRUCT<year INT64, `group` STRING, number INT64, name STRING, corporate_number STRING, description STRING, amount FLOAT64, primary BOOLEAN>>,
#     outcome ARRAY<STRUCT<goal STRING, indicator STRING, unit STRING, target STRING, target_year INT64, items ARRAY<STRUCT<year INT64, achievement FLOAT64, target FLOAT64>>>>,
#     outcome_difficulty_reason STRING,
#     outcome_alternative ARRAY<STRUCT<goal STRING, indicator STRING, unit STRING, target STRING, target_year INT64, items ARRAY<STRUCT<year INT64, achievement FLOAT64, target FLOAT64>>>>,
#     output ARRAY<STRUCT<goal STRING, indicator STRING, unit STRING, target STRING, target_year INT64, items ARRAY<STRUCT<year INT64, achievement FLOAT64, expected FLOAT64>>>>,
#     unit_cost ARRAY<STRUCT<reason STRING, unit STRING, items ARRAY<STRUCT<year INT64, unit_cost STRING, calculation STRING>>>>
# )
# FROM FILES(
#     format='NEWLINE_DELIMITED_JSON',
#     uris = [
#         'gs://judgit/2023-11-09/judgit.2023-11-09.bq.ndjson'
#     ],
#     max_bad_records = 0
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []
